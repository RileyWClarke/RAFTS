# %%
# %load_ext autoreload
# %autoreload 2

import os
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import iqr
from astropy.coordinates import SkyCoord, EarthLocation, AltAz, ICRS
from astropy.time import Time
from astropy.timeseries import LombScargle
from astropy.wcs import WCS
from astropy import units as u
from astropy.io import fits
from astropy import constants
from astropy.modeling.models import BlackBody
from astropy.visualization import quantity_support
from tqdm import tqdm

# %%
#Move up to RAFTS directory
if os.getcwd().endswith('/RAFTS'):
    pass
else:
    os.chdir('..')

# %%
pwd
# Out:
# '/Users/fbianco/RAFTS'

# %%
# !pip install photutils
# Out:
# Requirement already satisfied: photutils in /opt/anaconda3/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/lib/python3.11/site-packages (from photutils) (1.26.4)
# Requirement already satisfied: astropy>=5.3 in /opt/anaconda3/lib/python3.11/site-packages (from photutils) (5.3.4)
# Requirement already satisfied: scipy>=1.10 in /opt/anaconda3/lib/python3.11/site-packages (from photutils) (1.11.4)
# Requirement already satisfied: pyerfa>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from astropy>=5.3->photutils) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in /opt/anaconda3/lib/python3.11/site-packages (from astropy>=5.3->photutils) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /opt/anaconda3/lib/python3.11/site-packages (from astropy>=5.3->photutils) (23.1)

# %%
from utils import filt_interp, dpar, dtan, lamb_eff_md, dcr_offset, celest_to_pa, inverse_Teff, inverseTeff, inverseWeff, lorentzian, find_min_max_adjacent, variance_weighted_mean, chrDistAng
import globals
import defs as defs


from config import *

# %%
hdu_list = fits.open('dwfflare/0a7936112f3150350b27277900f88de2_c4d_151218_061807_ooi_g_v1.fits.fz')
hdu_list.info()
# Out:
# Filename: dwfflare/0a7936112f3150350b27277900f88de2_c4d_151218_061807_ooi_g_v1.fits.fz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     251   ()
#   1  S29           1 CompImageHDU    129   (2046, 4094)   float32
#   2  S31           1 CompImageHDU    129   (2046, 4094)   float32
#   3  S25           1 CompImageHDU    129   (2046, 4094)   float32
#   4  S26           1 CompImageHDU    129   (2046, 4094)   float32
#   5  S27           1 CompImageHDU    129   (2046, 4094)   float32
#   6  S28           1 CompImageHDU    129   (2046, 4094)   float32
#   7  S20           1 CompImageHDU    129   (2046, 4094)   float32
#   8  S21           1 CompImageHDU    129   (2046, 4094)   float32
#   9  S22           1 CompImageHDU    129   (2046, 4094)   float32
#  10  S23           1 CompImageHDU    129   (2046, 4094)   float32
#  11  S24           1 CompImageHDU    129   (2046, 4094)   float32
#  12  S14           1 CompImageHDU    129   (2046, 4094)   float32
#  13  S15           1 CompImageHDU    129   (2046, 4094)   float32
#  14  S16           1 CompImageHDU    129   (2046, 4094)   float32
#  15  S17           1 CompImageHDU    129   (2046, 4094)   float32
#  16  S18           1 CompImageHDU    129   (2046, 4094)   float32
#  17  S19           1 CompImageHDU    129   (2046, 4094)   float32
#  18  S8            1 CompImageHDU    129   (2046, 4094)   float32
#  19  S9            1 CompImageHDU    129   (2046, 4094)   float32
#  20  S10           1 CompImageHDU    129   (2046, 4094)   float32
#  21  S11           1 CompImageHDU    129   (2046, 4094)   float32
#  22  S12           1 CompImageHDU    129   (2046, 4094)   float32
#  23  S13           1 CompImageHDU    129   (2046, 4094)   float32
#  24  S1            1 CompImageHDU    129   (2046, 4094)   float32
#  25  S2            1 CompImageHDU    129   (2046, 4094)   float32
#  26  S3            1 CompImageHDU    129   (2046, 4094)   float32
#  27  S4            1 CompImageHDU    127   (2046, 4094)   float32
#  28  S5            1 CompImageHDU    127   (2046, 4094)   float32
#  29  S6            1 CompImageHDU    127   (2046, 4094)   float32
#  30  S7            1 CompImageHDU    127   (2046, 4094)   float32
#  31  N1            1 CompImageHDU    129   (2046, 4094)   float32
#  32  N2            1 CompImageHDU    129   (2046, 4094)   float32
#  33  N3            1 CompImageHDU    129   (2046, 4094)   float32
#  34  N4            1 CompImageHDU    127   (2046, 4094)   float32
#  35  N5            1 CompImageHDU    127   (2046, 4094)   float32
#  36  N6            1 CompImageHDU    127   (2046, 4094)   float32
#  37  N7            1 CompImageHDU    127   (2046, 4094)   float32
#  38  N8            1 CompImageHDU    129   (2046, 4094)   float32
#  39  N9            1 CompImageHDU    129   (2046, 4094)   float32
#  40  N10           1 CompImageHDU    129   (2046, 4094)   float32
#  41  N11           1 CompImageHDU    129   (2046, 4094)   float32
#  42  N12           1 CompImageHDU    129   (2046, 4094)   float32
#  43  N13           1 CompImageHDU    129   (2046, 4094)   float32
#  44  N14           1 CompImageHDU    129   (2046, 4094)   float32
#  45  N15           1 CompImageHDU    129   (2046, 4094)   float32
#  46  N16           1 CompImageHDU    129   (2046, 4094)   float32
#  47  N17           1 CompImageHDU    129   (2046, 4094)   float32
#  48  N18           1 CompImageHDU    129   (2046, 4094)   float32
#  49  N19           1 CompImageHDU    129   (2046, 4094)   float32
#  50  N20           1 CompImageHDU    129   (2046, 4094)   float32
#  51  N21           1 CompImageHDU    129   (2046, 4094)   float32
#  52  N22           1 CompImageHDU    129   (2046, 4094)   float32
#  53  N23           1 CompImageHDU    129   (2046, 4094)   float32
#  54  N24           1 CompImageHDU    129   (2046, 4094)   float32
#  55  N25           1 CompImageHDU    129   (2046, 4094)   float32
#  56  N26           1 CompImageHDU    129   (2046, 4094)   float32
#  57  N27           1 CompImageHDU    129   (2046, 4094)   float32
#  58  N28           1 CompImageHDU    129   (2046, 4094)   float32
#  59  N29           1 CompImageHDU    129   (2046, 4094)   float32
#  60  N31           1 CompImageHDU    129   (2046, 4094)   float32

# %%
hdu_list[16].data
# Out:
# array([[28.64088 , 31.617392, 24.957178, ..., 27.005594, 32.783024,
#         29.117338],
#        [20.971172, 30.57876 , 24.09615 , ..., 23.898054, 27.95859 ,
#         20.740602],
#        [28.406326, 25.357933, 29.101353, ..., 29.05602 , 25.20106 ,
#         18.529772],
#        ...,
#        [26.60759 , 34.178654, 29.469402, ..., 30.430195, 37.16763 ,
#         21.072706],
#        [22.315039, 34.979946, 32.176346, ..., 27.95241 , 32.472675,
#         18.84519 ],
#        [37.708824, 38.4955  , 28.122744, ..., 32.688633, 38.295967,
#         35.173634]], dtype=float32)

# %%
imnames = np.array(os.listdir('dwfflare'))
imnames = np.array([i for i in imnames if i.endswith("fits.fz") or i.endswith("fits")])
len(imnames)
# Out:
# 74

# %%
print(f"image sequence length {len(imnames)}")
# Out:
# image sequence length 74

# %%
#Collect DATE-OBS list
datelist = []

for i, imname in enumerate(imnames):
    try:
        image_header = fits.getheader('dwfflare/' + imname, ext=0)
        datelist.append(image_header['DATE-OBS'])

    except:
        print(i, 'EXT not found')
        datelist.append(image_header['DATE-OBS'])

datearr = np.array(datelist)
len(datearr)
# Out:
# 74

# %%
#Find .fits files that are missing S18 extension
badinds = []
for i, imname in enumerate(imnames):
    try:
        image_data = fits.getheader('dwfflare/' + imname, ext=16)

    except:
        print(i, 'EXT not found')
        badinds.append(i)

badinds = np.array(badinds)
print(f"bad images {badinds}")
# Out:
# bad images []

# %%
mask = np.ones(len(imnames), dtype=int)
if len(badinds) > 0:
    mask[badinds] = 0

mask = mask > 0
mask
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
imnames_timeordered = imnames[mask][np.argsort(datearr[mask])]
np.save('Outdata/imnames_timeordered.npy', imnames_timeordered)

# %%
for i, imname in enumerate(imnames_timeordered[0:40:20]):

    image_data = fits.getdata(ROOTDIR + '/dwfflare/' + imname, ext=16)
    image_header = fits.getheader(ROOTDIR + '/dwfflare/' + imname, ext=0)

    plt.imshow(np.rot90(image_data), cmap='gray', clim=(0,100))
    plt.title(image_header['DATE-OBS'])
    print(imname, i)
    plt.gca().invert_yaxis()
    #plt.gca().invert_xaxis()
    plt.xlim(250,750)
    plt.ylim(1500,2000)
    plt.show()
# Out:
# b5179de7a72a8849306cf70093d016bc_c4d_151218_054742_ooi_g_v1.fits.fz 0
# 86dc03d642083c4411ef7acb103b7ed6_c4d_151218_060346_ooi_g_v1.fits.fz 1

# %% [markdown]
# # SAVE FITS FILES FOR EXT 16 ONLY

# %%
#ONLY NEED TO DO IT ONCE
for name in imnames_timeordered:
    defs.makefitsfromext(ROOTDIR + '/dwfflare/' + name, ext=16, outdir=ROOTDIR + '/dwfflare/dwfflareS18/'+ name[:-8] + '_S18.fits.fz')

# %%
times = []

for imname in imnames_timeordered:
    imname = imname[:-8] + '_S18' + imname[-8:]
    file = 'dwfflare/dwfflareS18/' + imname 
    header = fits.getheader('dwfflare/dwfflareS18/' + imname)
    time = Time(header['DATE-OBS'])
    times.append(time)

len(times)
# Out:
# 74

# %%
#Look at first 10 imgs
for i, imname in enumerate(imnames_timeordered[0:60:30]):
    imname = imname[:-8] + '_S18' + imname[-8:]
    file = 'dwfflare/dwfflareS18/' + imname 
    data = fits.getdata('dwfflare/dwfflareS18/' + imname)
    header = fits.getheader('dwfflare/dwfflareS18/' + imname)
    wcs = WCS(header)
    time = Time(header['DATE-OBS'])

    print('Img {}'.format(i))
    plt.figure(figsize=(16,8))
    plt.imshow(data, cmap='Greys_r', clim=(0,100))
    plt.title('{}'.format(time))
    plt.xticks([])
    plt.yticks([])
    plt.show()
# Out:
# Img 0
# Img 1
