# %% [markdown]
# # ZTF

# %%
import matplotlib.pyplot as plt
import numpy as np

import astropy.units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.wcs import WCS
from astropy.visualization import astropy_mpl_style
from astropy.io.votable import parse

from utils import *
from config import *

plt.style.use(astropy_mpl_style)

# %% [markdown]
# ## ZTF Lightcurves

# %%
def plot_lcv(mintime, maxtime, ra, dec, radius, band):

    votable = parse('https://irsa.ipac.caltech.edu/cgi-bin/ZTF/nph_light_curves?POS=CIRCLE%20'
                    +str(ra)+'%20'+str(dec)+'%20'+str(radius)+'&TIME='+str(mintime)+'%20'+str(maxtime)+'&BANDNAME='+band)

    table = votable.get_first_table()
    data = table.array  
    ids = np.unique(data['oid'])

    am1 = np.zeros(len(data['mjd'][data['oid'] == ids[0]]))
    am2 = np.zeros(len(data['mjd'][data['oid'] == ids[1]]))

    mtn = EarthLocation.of_site('Palomar')

    i=0
    j=0
    for ra, dec, t in zip(data['ra'][data['oid'] == ids[0]], data['dec'][data['oid'] == ids[0]], data['mjd'][data['oid'] == ids[0]]):

        mjd = Time(t, format='mjd')
        flraltaz = SkyCoord(ra = ra * u.degree, dec = dec*u.degree).transform_to(AltAz(obstime = mjd, location=mtn))
        zd = 90 - flraltaz.alt.value
        am1[i] = 1 / np.cos(np.deg2rad(zd))
        i+=1

    for ra, dec, t in zip(data['ra'][data['oid'] == ids[1]], data['dec'][data['oid'] == ids[1]], data['mjd'][data['oid'] == ids[1]]):

        mjd = Time(t, format='mjd')
        flraltaz = SkyCoord(ra = ra * u.degree, dec = dec*u.degree).transform_to(AltAz(obstime = mjd, location=mtn))
        zd = 90 - flraltaz.alt.value
        am2[j] = 1 / np.cos(np.deg2rad(zd))
        j+=1

    plt.scatter(data['mjd'][data['oid'] == ids[0]], data['mag'][data['oid'] == ids[0]], 
            c = am1, cmap='viridis')
    plt.scatter(data['mjd'][data['oid'] == ids[1]], data['mag'][data['oid'] == ids[1]], 
                c = am2, cmap='viridis')
    plt.ylim(18.0,14.0)
    plt.xlabel('MJD (days)')
    plt.ylabel('g (mag)')
    plt.tick_params(labelsize=8)

    for i in np.arange(int(mintime)+0.288, int(maxtime)+0.288, 3):
        plt.annotate('LSST', xy = (i-0.3,15), xytext=(i-0.3,14.4), color='grey')
        plt.annotate('', xy = (i,15), xytext=(i,14.5), arrowprops = dict(facecolor='gray', color='grey', width=2, headwidth=6))

    cbar = plt.colorbar()
    cbar.set_label('Airmass', rotation=270, labelpad=20)
    plt.title("ZTF {}".format(ids[0]))
    plt.savefig('Figures/flare1_lc.png', dpi=300, bbox_inches='tight')

plot_lcv(58882,58890,get_flr_coord('flare1')[0],get_flr_coord('flare1')[1], 0.0001, 'g')
# Out:
# /var/folders/yy/7pyksq_x7bgc3xfdxf46nphm0000gn/T/ipykernel_68767/3177709448.py:44: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.annotate('', xy = (i,15), xytext=(i,14.5), arrowprops = dict(facecolor='gray', color='grey', width=2, headwidth=6))

# %% [markdown]
# ## ZTF Delta Position Plots:

# %%
filename = "srcext/20200206287824_000819_sciimg.fits"

hdulist = fits.open(filename)

# %%
header = hdulist[0].header
header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32
# NAXIS   =                    2
# NAXIS1  =                 3072
# NAXIS2  =                 3080
# BUNIT   = 'Data Value'
# ORIGIN  = 'Zwicky Transient Facility' / Data origin
# OBSERVER= 'ZTF Robotic Observing Software' / Observer
# ROBOSOFT= '0.99.12  December 9, 2019' / Robotic software version
# FITSSOFT= '0.99.12  December 9, 2019' / FITS software version
# INSTRUME= 'ZTF/MOSAIC'         / Instrument name
# DETECTOR= '        '           / Detector controller
# DETSOFT = '        '           / Detector software version
# DETFIRM = '        '           / Detector firmware version
# IMGTYPE = 'object  '           / Image type
# EXPOSURE=                  30. / Total Exposure Time (s)
# EXPTIME =                  30. / Requested Exposure Time (s)
# MODE_NUM=                    0 / Mode identifying key
# CCDSUM  = '1 1     '           / CCD binning
# PIXSCALE=                1.012 / Pixel scale, in arcsec per pixel
# FILENAME= 'ztf_20200206287824_000819_zg_c13_o.fits' / File name
# ORIGNAME= 'ztf_20200206287824_000819_zg_c13_o.fits' / Original file name
# FRAMENUM=                  479 / Detector frame number
# HEADTEMP=              160.162 / Cryo cooler cold head temp (K)
# DEWPRESS=               -9999. / Dewar pressure (milli-torr)
# DETHEAT =                  4.9 / Detector focal plane heater power (%)
# CCDTMP01=              167.884 / CCD temperature 01 (K)
# CCDTMP02=              173.221 / CCD temperature 02 (K)
# CCDTMP03=              165.352 / CCD temperature 03 (K)
# CCDTMP04=               167.47 / CCD temperature 04 (K)
# CCDTMP05=              165.379 / CCD temperature 05 (K)
# CCDTMP06=              163.608 / CCD temperature 06 (K)
# CCDTMP07=              166.156 / CCD temperature 07 (K)
# CCDTMP08=              166.111 / CCD temperature 08 (K)
# CCDTMP09=              165.953 / CCD temperature 09 (K)
# CCDTMP10=              163.765 / CCD temperature 10 (K)
# CCDTMP11=              164.396 / CCD temperature 11 (K)
# CCDTMP12=              166.406 / CCD temperature 12 (K)
# CCDTMP13=              167.135 / CCD temperature 13 (K)
# CCDTMP14=              165.375 / CCD temperature 14 (K)
# CCDTMP15=              166.089 / CCD temperature 15 (K)
# CCDTMP16=               167.23 / CCD temperature 16 (K)
# INST_X  =             1.64E-06 / Hexapod X (RA) axis position (mm)
# INST_Y  =         -7.58558E-07 / Hexapod Y (Dec) axis position (mm)
# FOCUSPOS=              1.42436 / Hexapod Z (Focus) axis position (mm)
# THETA_X =             0.328828 / Hexapod rotation about INST_X (deg)
# THETA_Y =             0.327849 / Hexapod rotation about INST_Y (deg)
# INST_ROT=         -8.80099E-07 / Hexapod rotation about Z axis (deg)
# FIELDID =                  819 / ZTF field ID number
# OBJRA   = '+12h00m00s'         / Queue object right ascension
# OBJDEC  = '+62d09m00s'         / Queue object declination
# OBJRAD  =                 180. / Object right ascension (deg)
# OBJDECD =                62.15 / Object declination (deg)
# EQUINOX =   2.000000000000E+03 / Equinox
# RA_RATE =                   0. / RA tracking rate ("/hr)
# DEC_RATE=                   0. / Dec tracking rate ("/hr)
# PROGRMPI= 'Kulkarni'           / Queue program PI
# REQUSTID=                  311 / Queue request ID
# QCOMMENT= 'ZUDS    '           / Queue comment
# TEMPTURE=                  5.5 / Outside air temperature (C)
# WINDSPD =                  3.8 / Outside wind speed
# WINDDIR =                 293. / Outside wind direction (deg)
# DEWPOINT=                 16.3 / Dewpoint (C)
# WETNESS =                   0. / Wetness sensor reading
# HUMIDITY=                  29. / Humidity
# PRESSURE=               -9999. / Atmospheric pressure, millibars
# CLOUDS  =               -9999. / Cloud sensor reading
# SUNAZ   =              315.317 / Sun azimuth (deg)
# SUNALT  =             -66.8196 / Sun altitude (deg)
# MOONRA  =              96.9898 / Moon J2000.0 R.A. (deg)
# MOONDEC =              22.9958 / Moon J2000.0 Dec. (deg)
# MOONALT =              65.1947 / Moon altitude (deg)
# MOONILLF=             0.882686 / Moon illuminated fraction (frac)
# MOONPHAS=              40.0599 / Moon phase angle (deg)
# MOONESB =                   0. / Moon excess in sky brightness V-band
# PROGRMID=                    2 / Queue program ID
# FILTERID=                    1 / Filter ID code
# FILTER  = 'ZTF_g   '           / Filter name
# FILTPOS =                    3 / Filter position
# OBSJD   =      2458885.7879051 / Julian day corresponds to UTC-OBS (day)
# OBSMJD  =        58885.2879051 / MJD corresponds to UTC-OBS (day)
# HJD     =      2458885.7879051 / Heliocentric Julian Day (days)
# OBLST   = '+08:10:53'          / Local Sidereal Time
# HOURANG = '-03:50:9.58'        / Hour angle
# HOURANGD=             -3.83599 / Hour angle (deg)
# RA      = '+12:00:00'          / Requested right ascension
# DEC     = '+62:09:00'          / Requested declination
# RAD     =                 180. / Requested right ascension (deg)
# DECD    =                62.15 / Requested declination (deg)
# TELRA   = '+11:59:60'          / Telescope right ascension
# TELDEC  = '+62:08:59.9'        / Telescope declination
# TELRAD  =                 180. / Telescope right ascension (deg)
# TELDECD =                62.15 / Telescope declination (deg)
# AZIMUTH =                33.37 / Telescope azimuth (deg)
# ELVATION=                44.11 / Telescope elevation (deg)
# TRACKRA =                   0. / TCS RA non-sidereal tracking rate ("/hr)
# TRACKDEC=                   0. / TCS Dec non-sidereal tracking rate ("/hr)
# AIRMASS =                1.435 / Airmass (Hardie)
# DOME_AZ =                 33.9 / Dome azimuth (deg)
# WINDSCAL=                   0. / Windscreen elevation (deg)
# OBSERVAT= 'Palomar Observatory' / Observatory
# TELESCOP= 'Palomar 48-inch'    / Observatory telescope
# OBSLON  =            -116.8598 / Observatory longitude (deg)
# OBSLAT  =              33.3573 / Observatory latitude (deg E)
# OBSALT  =                1668. / Observatory altitude (m)
# DOMESTAT= 'Open    '           / Dome status at beginning of exposure
# SHUTOPEN= '2020-02-06T06:54:36.220' / Shutter open time
# SHUTCLSD= '2020-02-06T06:55:06.183' / Shutter close time
# CDS0    = '#eval RGsettleT'
# CDS1    = '#eval PixelT'       / 2 - 1
# CDS2    = '#eval PixelT'       / 2 - 1 + SWsettleT
# CDS3    = '#eval PixelT - 2'
# PIXSCALX=                1.012 / Pixel scale in X
# PIXSCALY=                1.012 / Pixel scale in Y
# NFRAMES =                    8 / number of frames in FITS file
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# EXTNAME = '2       '
# HDUVERS =                    1
# CCD_ID  =                   13 / ID value of CCD detector
# CCDNAME = 'S13     '           / Detector name or serial number
# AMP_ID  =                    1 / ID value of CCD amplifier
# AMP_NAME= 'G       '           / Name of CCD amplifier
# GAIN    =                  5.8 / Gain e-/adu
# READNOI =                  9.2 / Read noise e-
# DARKCUR =                   1. / Dark current e-/s @ 150 K
# WCSVERS = '2.1     '           / WCS version number
# WCSAXES =                    2 / Number of WCS axes
# WCSNAME = 'ZTF     '           / Name of the WCS coordinate system
# RADESYS = 'ICRS    '           / Coordinate reference system
# CTYPE1  = 'RA---TPV'           / Name of coord X axis
# CTYPE2  = 'DEC--TPV'           / Name of coord Y axis
# CRPIX1  =   1.536500000000E+03 / Coord system X ref pixel
# CRPIX2  =   1.540500000000E+03 / Coord system Y ref pixel
# CRVAL1  =   1.856835609597E+02 / Coord system value at CRPIX1
# CRVAL2  =   6.533824114106E+01 / Coord system value at CRPIX2
# CUNIT1  = 'deg     '           / Coordinate units for X axis
# CUNIT2  = 'deg     '           / Coordinate units for Y axis
# CD1_1   =  -2.801339715523E-04 / WCS matrix
# CD1_2   =  -2.536593942998E-05 / WCS matrix
# CD2_1   =   2.528212504428E-05 / WCS matrix
# CD2_2   =  -2.801567739022E-04 / WCS matrix
# HISTORY executed CorrectFloatingBias at 2020-02-05T22:56:55
# HISTORY executed instrphotcal.pl at 2020-02-05T22:59:05
# CCD_ROT =                   0. / CCD rotation angle
# HISTORY   Astrometric solution by SCAMP version 2.0.4 (2018-09-05)
# COMMENT   (c) 2010-2013 IAP/CNRS/UPMC
# COMMENT
# PV1_0   =  -1.655656285640E-05 / Projection distortion parameter
# PV1_1   =   1.000312103302E+00 / Projection distortion parameter
# PV1_2   =   1.239753032745E-05 / Projection distortion parameter
# PV1_4   =   3.666744528750E-04 / Projection distortion parameter
# PV1_5   =  -5.826398866836E-04 / Projection distortion parameter
# PV1_6   =   3.720844090922E-04 / Projection distortion parameter
# PV1_7   =  -5.482281686996E-04 / Projection distortion parameter
# PV1_8   =   5.741781214635E-04 / Projection distortion parameter
# PV1_9   =  -4.305016879727E-04 / Projection distortion parameter
# PV1_10  =   1.410051456792E-04 / Projection distortion parameter
# PV1_12  =   6.014079602777E-04 / Projection distortion parameter
# PV1_13  =   7.500465813421E-04 / Projection distortion parameter
# PV1_14  =  -2.703122936735E-03 / Projection distortion parameter
# PV1_15  =  -1.339562158812E-04 / Projection distortion parameter
# PV1_16  =   1.260484628854E-04 / Projection distortion parameter
# PV2_0   =   3.197510943658E-06 / Projection distortion parameter
# PV2_1   =   9.999057613845E-01 / Projection distortion parameter
# PV2_2   =   1.675035289599E-04 / Projection distortion parameter
# PV2_4   =  -2.939730408124E-04 / Projection distortion parameter
# PV2_5   =   4.369749345500E-04 / Projection distortion parameter
# PV2_6   =   5.140568995215E-06 / Projection distortion parameter
# PV2_7   =  -1.426714498496E-04 / Projection distortion parameter
# PV2_8   =  -5.241916042677E-06 / Projection distortion parameter
# PV2_9   =  -5.924674135072E-04 / Projection distortion parameter
# PV2_10  =   4.196520293276E-05 / Projection distortion parameter
# PV2_12  =  -1.086684585694E-03 / Projection distortion parameter
# PV2_13  =  -1.496798153224E-03 / Projection distortion parameter
# PV2_14  =   2.244193894771E-03 / Projection distortion parameter
# PV2_15  =  -2.167944399613E-04 / Projection distortion parameter
# PV2_16  =  -3.492820928721E-04 / Projection distortion parameter
# FGROUPNO=                    1 / SCAMP field group label
# ASTIRMS1=   0.000000000000E+00 / Astrom. dispersion RMS (intern., high S/N)
# ASTIRMS2=   0.000000000000E+00 / Astrom. dispersion RMS (intern., high S/N)
# ASTRRMS1=   2.141492373551E-05 / Astrom. dispersion RMS (ref., high S/N)
# ASTRRMS2=   1.880535912250E-05 / Astrom. dispersion RMS (ref., high S/N)
# ASTINST =                    1 / SCAMP astrometric instrument label
# FLXSCALE=   0.000000000000E+00 / SCAMP relative flux scale
# MAGZEROP=   0.000000000000E+00 / SCAMP zero-point
# PHOTIRMS=   0.000000000000E+00 / mag dispersion RMS (internal, high S/N)
# PHOTINST=                    1 / SCAMP photometric instrument label
# PHOTLINK=                    F / True if linked to a photometric field
# ASTROMN =                  391
# ASTCHI2 =     11.0511999130249
# SCAMPFIL= 'gaia_000819_c13_q2.fits'
# SCAMPPTH= '/ztf/ops/static/rc49/astrom'
# CALNOTE1= '*** photometric-calibration keywords below are from PSF-fitting:'
# CALNOTE2= '*** will also be applicable to aperture measurements on point'
# CALNOTE3= '*** sources using psf_mag-aper_mag corrections below (if available)'
# NMATCHES=                  172 / Number of photometric calibrators used
# MAGZP   =            25.995659 / Magnitude zero point for PSF-photometry [mag]
# MAGZPUNC=         0.0000784874 / Magnitude zero point uncertainty [mag]
# MAGZPRMS=             0.042141 / Magnitude zero point RMS deviation [mag]
# CLRCOEFF=            -0.055872 / Color coefficient from linear fit
# CLRCOUNC=         0.0001591942 / Color coefficient uncertainty from linear fit
# ZPCLRCOV=          -0.00010417 / Covariance in MAGZP and CLRCOEFF [mag^2]
# PCOLOR  = 'g - R   '           / Calibrator color used for PSF-fit calibration
# SATURATE=            58644.152 / Saturation value in final science image [DN]
# ZPMED   =            25.961000 / Mag zero point from median of mag diffs [mag]
# ZPAVG   =            25.959099 / Mag zero point from average of mag diffs [mag]
# ZPRMSALL=             0.044478 / Mag zero point RMS from all mag diffs [mag]
# CLRMED  =                0.604 / Median calibrator color [mag]
# CLRAVG  =                0.654 / Average calibrator color [mag]
# CLRRMS  =             0.254670 / RMS in calibrator color [mag]
# FIXAPERS= '2,3,4,6,10,14'      / fixed aperture diameters used [pixels]
# APCOR1  =          -1.93987453 / PSF_mag - AP_mag for AP.diam= 2.0 pix.
# APCORUN1=         0.0044453809 / Uncertainty in APCOR1 [mag]
# APCOR2  =          -1.21039295 / PSF_mag - AP_mag for AP.diam= 3.0 pix.
# APCORUN2=         0.0020927424 / Uncertainty in APCOR2 [mag]
# APCOR3  =          -0.78073400 / PSF_mag - AP_mag for AP.diam= 4.0 pix.
# APCORUN3=         0.0016780599 / Uncertainty in APCOR3 [mag]
# APCOR4  =          -0.34708300 / PSF_mag - AP_mag for AP.diam= 6.0 pix.
# APCORUN4=         0.0017370358 / Uncertainty in APCOR4 [mag]
# APCOR5  =          -0.08307800 / PSF_mag - AP_mag for AP.diam=10.0 pix.
# APCORUN5=         0.0023161237 / Uncertainty in APCOR5 [mag]
# APCOR6  =          -0.02427000 / PSF_mag - AP_mag for AP.diam=14.0 pix.
# APCORUN6=         0.0031482211 / Uncertainty in APCOR6 [mag]
# CCDID   =                   13
# QID     =                    2
# RCID    =                   49
# EXPID   =            113128790
# INFOBITS=                    0 / infoBits string; bit(s) = null
# SEEING  =                3.474 / seeing FWHM [pixels]
# CIDPMASK=             39649011 / calibration DB ID for pmask image input
# CIDBIAS =            113149002 / calibration DB ID for bias image input
# CIDHIFLT=            113149014 / calibration DB ID for hi-nu flat image input
# CIDLOFLT=                49015 / calibration DB ID for low-nu flat image input
# MAGLIM  =                19.39 / 5-sigma mag-limit in PSF-fit catalog [mag]
# BIT00   =                    0 / MEDIAN BACKGROUND LEVEL is >  4000.0 DN
# BIT01   =                    1 / ROBUST PIXEL NOISE (RMS) is > 100.0 DN
# BIT02   =                    2 / PERCENT OF SATURATED PIXELS is > 50.0%
# BIT03   =                    3 / IMAGE SEEING (FWHM) is > 5.0"
# BIT04   =                    4 / MAGLIM FROM PSF CATALOG UNCERTS is < 17.5 mag
# BIT05   =                    5 / MAGLIM FROM EMPIRICAL FORMULA is < 17.5 mag
# BIT06   =                    6 / NUMBER OF PSF CATALOG SOURCES is < 10
# BIT07   =                    7 / NUMBER OF SEXTRACTOR CAT SOURCES is < 20
# BIT08   =                    8 / PHOTOMETRIC CALIBRATION NOT POSSIBLE
# BIT09   =                    9 / NUMBER OF PHOTOMETRIC CALIBRATORS is < 30
# BIT10   =                   10 / NUMBER OF MATCHES FOR PHOTOMETRIC CAL < 5
# BIT11   =                   11 / RMS in PHOTCAL RESIDUALS (ZPs) is > 0.2 mag
# BIT12   =                   12 / ASTROMETRIC CALIBRATION NOT POSSIBLE
# BIT13   =                   13 / PCT OF REF-CAT MATCHES FOR ASTROM is < 0%
# BIT14   =                   14 / NUMBER OF MATCHES FOR ASTROM CAL is < 100
# BIT15   =                   15 / MIN NUM OF IN-GRID MATCHES FOR ASTROM is < 5
# BIT16   =                   16 / REL-PIXEL SCALE OUT OF RANGE: -0.20% - 2.00%
# BIT17   =                   17 / PCT CHANGE IN SCAMP CHI-SQUARE is > 0.0%
# BIT18   =                   18 / CHI-SQUARE FROM SECOND PASS SCAMP is > 55
# BIT19   =                   19 / MAX IN-GRID MEDIAN ASTROM RESID is > 0.7"
# BIT20   =                   20 / PSF CREATION (HENCE PSF-FIT PHOT) NOT POSSIBLE
# BIT21   =                   21 / PCT OF DETECTED MATCHES FOR ASTROM is < 50%
# STATUS  =                    1 / overall processing flag: 0 = bad; 1 = usable
# CREATED = '2020-02-05T23:00:06' / File creation date/time (Pacific Time)
# DBPID   =        1131287904915 / Database processed-image ID
# PROCVSN =                    1 / Processing version
# DBFIELD =                  819 / Database field
# DBNID   =                 1131 / Database night ID
# DBEXPID =            113128790 / Database exposure ID
# DBRID   =          11312879049 / Database raw-image ID
# DBRCID  =                   49 / Database readout-channel ID
# DBFID   =                    1 / Database filter ID
# DBPIPEID=                   15 / Database pipeline ID

# %%
from astropy import units as u
from astropy.units import hourangle, degree, hour
from astropy.coordinates import SkyCoord, AltAz, EarthLocation, FK5, Angle
from astropy.time import Time, TimeDelta
import datetime
import time
LaPalmaLatitude = (28 + 45 / 60 + 49 / 60 / 60) * u.degree
LaPalmaLongitude = - (17 + 53/ 60 + 41 / 60 / 60) * u.degree
SubLatitude = (19 + 49 / 60 + 32 / 3600) * u.degree 
SubLongitude = - (155 + 28 / 60 + 34 / 3600) * u.degree 
APOLatitude = (32 + 46 / 60 + 49 / 60 / 60) * u.degree 
APOLongitude = - (105 + 49/60 +  133 / 60 / 60) * u.degree 
KPLatitude = (31 + 57 / 60 + 12 / 60 / 60 ) * u.degree 
KPLongitude = -(7*15 + 26 / 60 + 28 / 60 / 60 ) * u.degree
LSLatitude = (29 + 15 / 60 + 27 / 60 / 60) * u.degree 
LSLongitude = - (70 + 44 / 60 + 15 / 60 / 60) * u.degree 
c = SkyCoord(ra=hdulist[0].header["TELRA"], dec=hdulist[0].header["TELDEC"], unit=(u.hourangle, u.deg))
print("image center coordinates", c.to_string())
# Out:
# image center coordinates 180 62.15
# WARNING: IllegalSecondWarning: 'second' was found  to be '60', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_formats]

# %%
locapo = EarthLocation(lat=APOLatitude,
          lon=APOLongitude, height=2788 * u.meter)
loclp = EarthLocation(lat=LaPalmaLatitude,
          lon=LaPalmaLongitude, height=2396 * u.meter)
locsub = EarthLocation(lat=SubLatitude,
          lon=SubLongitude, height=4139 * u.meter) 
locls = EarthLocation(lat=LSLatitude,
          lon=LSLongitude, height=2400 * u.meter) 

lockp = EarthLocation(lat=KPLatitude,
          lon=KPLongitude, height=1925 * u.meter) 

locpal = EarthLocation(lat=header["OBSLAT"],
          lon=header["OBSLON"], height=header["OBSALT"] * u.meter) 

# Read the start time and exposure time of the image from the header
#sidtime = Time(datetime.datetime.strptime(header['DATE-OBS'] + 'T' + 
#                             header['TAIHMS'].split('.')[0], 
#                             '%Y-%m-%dT%H:%M:%S'),# %HH:%MM:%SS.SS'), 
#                 location=locapo)

sidtime = Time(header["OBSMJD"], format='mjd', location=locpal)
print(sidtime)
# determine the sidereal time at the mid point of the exposure
sidereal = sidtime.sidereal_time('mean')
print("Sidereal time", sidereal)
# Out:
# 58885.2879051
# Sidereal time 8h10m41.7882934s

# %%
def pa(ha, lat, dec):

  return np.rad2deg(np.arctan2(np.sin(ha), np.cos(dec) * \
                np.tan(lat) - np.sin(dec) * np.cos(ha)))

# %%
def compute_paral_angles(header, loc, 
                         ra_key="RA", dec_key="DEC", exptime="EXPTIME",
                         acqtime_key="TAIHMS", date_key='DATE-OBS'):
    """Calculates the parallactic angle for a frame, taking coordinates and
    local sidereal time from fits-headers (frames taken in an alt-az telescope 
    with the image rotator off).
    
    The coordinates in the header are assumed to be J2000 FK5 coordinates.
    The spherical trigonometry formula for calculating the parallactic angle
    is taken from Astronomical Algorithms (Meeus, 1998).
    
    Parameters
    ----------
    header : dictionary
        Header of current frame.
    ra_key, dec_key, exptime, lst_key, acqtime_key, date_key : strings
        Keywords where the values are stored in the header.
        
    Returns
    -------
    pa.value : float
        Parallactic angle in degrees for current header (frame).
    """                                    
    latitude = loc.lat

    sidtime = Time(header[date_key], format='mjd', location=loc)
    
    print("zen angle {}".format(AltAz(alt=header["ELVATION"] * u.degree, 
                             az=header["AZIMUTH"] * u.degree,
                obstime=sidtime, 
                 location=loc
                 ).zen))
    
    # equatorial coordinates in J2000
    ra = header[ra_key]                                                         
    dec = header[dec_key]  
    r, m =  int(ra / 15) , int((ra / 15 - int(ra / 15)) * 60)
    s = ((ra / 15 - r) * 60. - m) * 60
    print("ra in hh:mm:ss", r, m, s)

    d, m =  int(dec) , int((dec - int(dec)) * 60)
    s = ((dec - d) * 60. - m) * 60
    print("dec in dd:mm:ss", d, m, s)

    coor = SkyCoord(ra=ra, dec=dec, 
                    unit=(degree,degree), frame=FK5, 
                    equinox='J2000.0')
    
    # recalculate for DATE-OBS (precession)
    coor_curr = coor.transform_to(FK5(equinox=sidtime))
    print("corrected coordinates", coor_curr.to_string(style='dms'))
    # new ra and dec in radians
    ra_curr = coor_curr.ra                                                      
    dec_curr = coor_curr.dec
    
    lst = sidtime.sidereal_time('mean')
    print("time {}, sidereal time {:.2f}".format(sidtime, lst))

    # for long exposures (spectra) you would need to calculate the mid time
    ##lst_split = lst.split(':')
    #exp_delay = (float(header[exptime]) * 0.5) / 3600
    ## solar to sidereal time
    #exp_delay = exp_delay * 1.0027 * u.hour                                                
    ##print(lst.hour)

    # hour angle in degrees
    hour_angle = ((lst.hour) - ra_curr.hour) * 15                          
    hour_angle = np.deg2rad(hour_angle)      
    print("HA: {} ({:.2f} rad)".format(lst, hour_angle))      

    print("observatory latitude {:.2f}".format(latitude))
    latitude = np.deg2rad(latitude)                                             
    # PA formula from Astronomical Algorithms 
    return (pa(hour_angle, latitude, dec_curr.radian)).value
    

print("Parallactic Angle {:.2f}".format(compute_paral_angles(header, 
                              locpal, ra_key="TELRAD", dec_key="TELDECD", acqtime_key="OBLST", date_key="OBSMJD")))
# Out:
# zen angle 45.89 deg
# ra in hh:mm:ss 12 0 0.0
# dec in dd:mm:ss 62 8 59.999999999994884
# corrected coordinates 180d15m25.29209345s 62d02m17.21658598s
# time 58885.2879051, sidereal time 8.18 hourangle
# HA: 8.178274525945758 hourangle (-1.01 rad)
# observatory latitude 33.36 deg
# Parallactic Angle -101.05

# %%
def compute_star_paral_angles(header, sra, sdec, loc, 
                         ra_key="RA", dec_key="DEC", exptime="EXPTIME",
                         acqtime_key="TAIHMS", date_key='DATE-OBS', verbose=True):
    """Calculates the parallactic angle for a frame, taking coordinates and
    local sidereal time from fits-headers (frames taken in an alt-az telescope 
    with the image rotator off).
    
    The coordinates in the header are assumed to be J2000 FK5 coordinates.
    The spherical trigonometry formula for calculating the parallactic angle
    is taken from Astronomical Algorithms (Meeus, 1998).
    
    Parameters
    ----------
    header : dictionary
        Header of current frame.
    ra_key, dec_key, exptime, lst_key, acqtime_key, date_key : strings
        Keywords where the values are stored in the header.
        
    Returns
    -------
    pa.value : float
        Parallactic angle in degrees for current header (frame).
    """                                    
    latitude = loc.lat

    sidtime = Time(header[date_key], format='mjd', location=loc)

    if verbose:
        print("zen angle {}".format(AltAz(alt=header["ELVATION"] * u.degree, 
                                az=header["AZIMUTH"] * u.degree,
                    obstime=sidtime, 
                    location=loc
                    ).zen))
    
    # equatorial coordinates in J2000
    ra = sra                                                 
    dec = sdec
    r, m =  int(ra / 15) , int((ra / 15 - int(ra / 15)) * 60)
    s = ((ra / 15 - r) * 60. - m) * 60
    if verbose:
        print("ra in hh:mm:ss", r, m, s)

    d, m =  int(dec) , int((dec - int(dec)) * 60)
    s = ((dec - d) * 60. - m) * 60
    if verbose:
        print("dec in dd:mm:ss", d, m, s)

    coor = SkyCoord(ra=ra, dec=dec, 
                    unit=(degree,degree), frame=FK5, 
                    equinox='J2000.0')
    
    # recalculate for DATE-OBS (precession)
    coor_curr = coor.transform_to(FK5(equinox=sidtime))
    if verbose:
        print("corrected coordinates", coor_curr.to_string(style='dms'))
    # new ra and dec in radians
    ra_curr = coor_curr.ra                                                      
    dec_curr = coor_curr.dec
    
    lst = sidtime.sidereal_time('mean')
    if verbose:
        print("time {}, sidereal time {:.2f}".format(sidtime, lst))

    # for long exposures (spectra) you would need to calculate the mid time
    ##lst_split = lst.split(':')
    #exp_delay = (float(header[exptime]) * 0.5) / 3600
    ## solar to sidereal time
    #exp_delay = exp_delay * 1.0027 * u.hour                                                
    ##print(lst.hour)

    # hour angle in degrees
    hour_angle = ((lst.hour) - ra_curr.hour) * 15                          
    hour_angle = np.deg2rad(hour_angle)
    if verbose:
        print("HA: {} ({:.2f} rad)".format(lst, hour_angle))      
    if verbose:
        print("observatory latitude {:.2f}".format(latitude))
    latitude = np.deg2rad(latitude)                                             
    # PA formula from Astronomical Algorithms 
    return (pa(hour_angle, latitude, dec_curr.radian)).value

# %%
def img_deltas(im1,im2,flr_coord,det_thr=10,ana_thr=10):

    mjd1 = Time(im1[0:4]+'-'+im1[4:6]+'-'+im1[6:8], format='isot').mjd + float(im1[8:14])
    mjd2 = Time(im2[0:4]+'-'+im2[4:6]+'-'+im2[6:8], format='isot').mjd + float(im2[8:14])

    #Read in images
    ep1file = getsciimg(filefracday=im1[0:14], paddedfield=im1[14:20], filtercode=im1[20:22],paddedccdid=im1[22:24],imgtypecode=im1[24:25],qid=im1[25:26])
    ep2file = getsciimg(filefracday=im2[0:14], paddedfield=im2[14:20], filtercode=im2[20:22],paddedccdid=im2[22:24],imgtypecode=im2[24:25],qid=im2[25:26])
    #Do SExtractor stuff
    ep1cat = srcext(im1[0:14]+'_'+im1[14:20]+'_'+'sciimg.fits', det_thresh=det_thr, ana_thresh=ana_thr, catname = im1[0:14]+'_'+im1[14:20]+'.cat')
    ep2cat = srcext(im2[0:14]+'_'+im2[14:20]+'_'+'sciimg.fits', det_thresh=det_thr, ana_thresh=ana_thr, catname = im2[0:14]+'_'+im2[14:20]+'.cat')
    
    #Crossmatch catalogs
    ind, d2d, d3d = xmatch(ep1cat, ep2cat)
   
    if len(ep1cat["ALPHA_SKY"]) > len(ep2cat["ALPHA_SKY"]):
        ep1ra = ep1cat["ALPHA_SKY"].values[ind]
        ep1dec = ep1cat["DELTA_SKY"].values[ind]
        ep2ra = ep2cat["ALPHA_SKY"].values
        ep2dec = ep2cat["DELTA_SKY"].values

    if len(ep1cat["ALPHA_SKY"]) < len(ep2cat["ALPHA_SKY"]):
        ep1ra = ep1cat["ALPHA_SKY"].values
        ep1dec = ep1cat["DELTA_SKY"].values
        ep2ra = ep2cat["ALPHA_SKY"].values[ind]
        ep2dec = ep2cat["DELTA_SKY"].values[ind]

    if len(ep1cat["X_IMAGE"]) > len(ep2cat["X_IMAGE"]):
        ep1x = ep1cat["X_IMAGE"].values[ind]
        ep1y = ep1cat["Y_IMAGE"].values[ind]
        ep2x = ep2cat["X_IMAGE"].values
        ep2y = ep2cat["Y_IMAGE"].values

    if len(ep1cat["X_IMAGE"]) < len(ep2cat["X_IMAGE"]):
        ep1x = ep1cat["X_IMAGE"].values
        ep1y = ep1cat["Y_IMAGE"].values
        ep2x = ep2cat["X_IMAGE"].values[ind]
        ep2y = ep2cat["Y_IMAGE"].values[ind]

    with fits.open('srcext/20200206287824_000819_sciimg.fits') as hdu:
        ep1header = hdu[0].header

    with fits.open('srcext/20200206302627_000819_sciimg.fits') as hdu:
        ep2header = hdu[0].header
        
    w1 = WCS(ep1header)
    w2 = WCS(ep2header)
    zen1 = calc_zenith(mjd1)
    zen2 = calc_zenith(mjd2)
    zen1x, zen1y = w1.wcs_world2pix(zen1.ra, zen1.dec, 1)
    zen2x, zen2y = w2.wcs_world2pix(zen2.ra, zen2.dec, 1)
    zen_ra = zen1.ra.value
    zen_dec = zen1.dec.value

    flr_ra = flr_coord[0]
    flr_dec = flr_coord[1]
   
    ##COMPUTE AIRMASSES & PARALLACTIC ANGLES-------------------------
    ep1am = np.zeros(len(ep1ra))
    ep2am = np.zeros(len(ep2ra))
    ep1pa = np.zeros(len(ep1ra))
    ep2pa = np.zeros(len(ep2ra))

    i=0
    j=0
    for ra, dec in zip(ep1ra, ep1dec):

        mtn = EarthLocation.of_site('Palomar')
        mjd = Time(58885.28807871, format='mjd')
        altaz = SkyCoord(ra = ra * u.degree, dec = dec*u.degree).transform_to(AltAz(obstime = mjd, location=mtn))
        zd = 90 - altaz.alt.value
        ep1am[i] = 1 / np.cos(np.deg2rad(zd))
        ep1pa[i] = compute_star_paral_angles(ep1header, ra, dec, mtn, ra_key="TELRAD", dec_key="TELDECD", acqtime_key="OBLST", date_key="OBSMJD", verbose=False)
        i+=1

    for ra, dec in zip(ep2ra, ep2dec):

        mtn = EarthLocation.of_site('Palomar')
        mjd = Time(58885.3026273, format='mjd')
        altaz = SkyCoord(ra = ra * u.degree, dec = dec*u.degree).transform_to(AltAz(obstime = mjd, location=mtn))
        zd = 90 - altaz.alt.value
        ep2am[j] = 1 / np.cos(np.deg2rad(zd))
        ep2pa[j] = compute_star_paral_angles(ep2header, ra, dec, mtn, ra_key="TELRAD", dec_key="TELDECD", acqtime_key="OBLST", date_key="OBSMJD", verbose=False)
        j+=1


    imaltaz = SkyCoord(ra = ep1header["TELRAD"] * u.degree, dec = ep1header["TELDECD"]*u.degree).transform_to(AltAz(obstime = mjd, location=mtn))
    zd = 90.0 * u.degree - imaltaz.alt
    #print("Telescope zenith angle: {}".format(zd))

    mean_ams = (ep1am + ep2am) / 2
    #-------------------------------------------

    #Calc delta coords, conv to arcsec
    d_ra = (ep1ra - ep2ra) * 3600
    d_dec = (ep1dec - ep2dec) * 3600
    d_x = ep1x - ep2x
    d_y = ep1y - ep2y
    d_pa = ep1pa - ep2pa

    #Calc zenith delta coord, conv to arcsec
    d_zra = (ep1ra.mean() - zen_ra) * 3600
    d_zdec = (ep1dec.mean() - zen_dec) * 3600
    d_zx = ep1x.mean() - zen1x
    d_zy = ep1y.mean() - zen1y

    #Calc centroid
    centroid = (sum(d_ra) / len(d_ra), sum(d_dec) / len(d_dec))

    #Find Flare star
    f_ind = np.where( (np.abs(ep1ra - flr_ra) == np.abs(ep1ra - flr_ra).min()) * (np.abs(ep1dec - flr_dec) == np.abs(ep1dec - flr_dec).min()) )[0][0]

    return d_x, d_y, mean_ams, d_pa, f_ind

d_x, d_y, mean_ams, d_pa, f_ind = img_deltas(get_img_string('flare1ep1'), 
                                             get_img_string('flare1ep3'), 
                                             get_flr_coord('flare1'))
# Out:
# Querying: https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2020/0206/287824/ztf_20200206287824_000819_zg_c13_o_q2_sciimg.fits
# Querying: https://irsa.ipac.caltech.edu/ibe/data/ztf/products/sci/2020/0206/302627/ztf_20200206302627_000819_zg_c13_o_q2_sciimg.fits
# Making SExtractor catalog of 20200206287824_000819_sciimg.fits...
# This catalogue already exists, moving on...
# Making SExtractor catalog of 20200206302627_000819_sciimg.fits...
# This catalogue already exists, moving on...
# Matching catalogs...

# %%
def dpix_plot(d_x, d_y, clr_vector, f_ind, clr_label=r'$\Delta$ PA (deg)', vmin=None, vmax=None):
    #Clip outliers
    x=d_x.copy()
    y=d_y.copy()
    clr_v=clr_vector.copy()
    x[np.concatenate([np.where((d_x > np.percentile(d_x, 98)) | (d_x < np.percentile(d_x, 2)))[0], 
                    np.where((d_y > np.percentile(d_y, 98)) | (d_y < np.percentile(d_y, 2)))[0]])] = np.nan
    y[np.concatenate([np.where((d_x > np.percentile(d_x, 98)) | (d_x < np.percentile(d_x, 2)))[0], 
                    np.where((d_y > np.percentile(d_y, 98)) | (d_y < np.percentile(d_y, 2)))[0]])] = np.nan
    clr_v[np.concatenate([np.where((d_x > np.percentile(d_x, 98)) | (d_x < np.percentile(d_x, 2)))[0], 
                    np.where((d_y > np.percentile(d_y, 98)) | (d_y < np.percentile(d_y, 2)))[0]])] = np.nan

    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    s = ax.scatter(x, y, c=clr_v, cmap='viridis', vmin=vmin, vmax=vmax, alpha=0.75)
    ax.scatter(x[f_ind], y[f_ind], color='red', s=100, marker='*', label='Flare star', alpha=0.75)
    #ax.plot([-4.3,d_zx],[-12.0,d_zy], c='gray',ls='--', label="to zenith")
    xlim = ax.get_xlim()
    cbar = fig.colorbar(s)
    cbar.set_label(clr_label, rotation=270, labelpad=20)
    cbar.ax.text(cbar.ax.get_xlim()[0] - (cbar.ax.get_xlim()[1] - cbar.ax.get_xlim()[0]) / 2, clr_v[f_ind], s=r'$\rightarrow$', fontsize=20, 
                color='red', ha='center', va='center', transform=cbar.ax.transData)

    # Move left y-axis and bottim x-axis to centre, passing through (0,0)
    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')

    # Eliminate upper and right axes
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # Show ticks in the left and lower axes only
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_xlabel(r"$\Delta$ X (px)", labelpad=150)
    ax.set_ylabel(r"$\Delta$ Y (px)", labelpad=150)
    ax.set_title(r'$t_1 - t_3$ pixel positions')
    #ax.set_xticks([-0.4,-0.2,0.2,0.4])
    ax.set_xlim(np.nanmin(x)- (np.nanmax(x) - np.nanmin(x))*0.2, np.nanmax(x) + (np.nanmax(x) - np.nanmin(x))*0.2)
    ax.set_ylim(np.nanmin(y)- (np.nanmax(y) - np.nanmin(y))*0.2, np.nanmax(y) + (np.nanmax(y) - np.nanmin(y))*0.2)
    ax.legend()
    ax.grid(False)

    plt.gca().set_aspect('equal')

dpix_plot(d_x,d_y,d_pa,f_ind)

# %%
plt.hist(d_pa, bins=30)
plt.vlines(d_pa[f_ind], 0, 25, color='r', ls='--', label='Flare Star')
plt.xlabel(r'$\Delta$ PA (deg)')
plt.ylabel(r'$N_{stars}$')
plt.title(r'$T_1-T_3$ $\Delta$PA')
plt.legend();

# %%
dpix_plot(d_x,d_y,mean_ams,f_ind, 'Airmass')

# %% [markdown]
# ## SDSS Check

# %%
with fits.open('frame-g-001302-4-0379.fits') as hdu:

    sdss_data1 = hdu[0].data
    sdss_header1 = hdu[0].header

date = sdss_header1['DATE-OBS']
hms = sdss_header1['TAIHMS']


w = WCS(sdss_header1)
mtn = EarthLocation.of_site('Apache Point Observatory')
mjd = Time(Time(date + ' ' + hms, format='iso', scale='utc').mjd, format='mjd')

zen = SkyCoord(AltAz(alt=90 * u.degree, az=0 * u.degree, obstime = mjd, location=mtn)).transform_to(ICRS())
zenaltaz = zen.transform_to(AltAz(obstime = mjd, location=mtn))
print('Zenith altaz:', zenaltaz)
zenx, zeny = w.wcs_world2pix(zen.ra, zen.dec, 1)
print('Zenith coords RA: {0}, Dec: {1}'.format(zen.ra, zen.dec))

tele_ra = sdss_header1['RA']
tele_dec = sdss_header1['DEC']
tele_az = sdss_header1['AZ']
tele_alt  = sdss_header1['ALT']

starcoord = SkyCoord(ra=get_flr_coord('flare1')[0]*u.degree, dec=get_flr_coord('flare1')[1] * u.degree, frame='icrs')
starcoord.to_string('hmsdms')

altaz = SkyCoord(ra = starcoord.ra, dec = starcoord.dec).transform_to(AltAz(obstime = mjd, location=mtn))
print('Alt = {}'.format(altaz.alt))
print('Az = {}'.format(altaz.az))
zd = zenaltaz.alt - altaz.alt
am = 1 / np.cos(np.deg2rad(zd))
print('Zenith angle: {}'.format(zd))
print('Airmass: {}'.format(am))

starx, stary = w.wcs_world2pix(starcoord.ra, starcoord.dec, 1)

plt.imshow(sdss_data1, interpolation='none', cmap='Greys', clim=(-1,3))
#plt.plot([starx, zenx],[stary,zeny],'--')
plt.xlim(0,2000)
plt.ylim(0,1500);
# Out:
# Zenith altaz: <SkyCoord (AltAz: obstime=51633.37402175926, location=(-1463969.30185172, -5166673.34223433, 3434985.71204565) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (125.14962035, 90.)>
# Zenith coords RA: 216.8797285184533 deg, Dec: 32.78231546411973 deg
# Alt = 52.524228432651626 deg
# Az = 339.43015700221963 deg
# Zenith angle: 37.47577156734732 deg
# Airmass: 1.2600636657164104
